# %%
import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

from pathlib import Path

results = pd.read_csv("runs/detect/train-3/results.csv")

results.head()
# Out:
#    epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0      1   39.5753         0.99887         1.40516         1.07586
# 1      2   77.6593         0.96006         0.86609         1.03382
# 2      3  115.1950         0.93360         0.70141         1.02993
# 3      4  152.7000         0.91578         0.64161         1.01748
# 4      5  190.1770         0.88094         0.58345         1.00479
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0               0.92667            0.94203           0.96058
# 1               0.96630            0.95834           0.98766
# 2               0.95562            0.95887           0.98877
# 3               0.97869            0.94451           0.98281
# 4               0.97147            0.96299           0.99138
#
#    metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 0              0.72537       0.89504       1.10376       1.02693  0.000662
# ...

# %%
results.columns

plt.figure(figsize=(10,5))

plt.plot(results["epoch"],results["train/box_loss"])

plt.grid()

plt.title("Box Loss")

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(results["epoch"],results["metrics/precision(B)"])

plt.grid()

plt.show()

# %%
print(results.iloc[-1])
#лучшие значения
# Out:
# epoch                     30.000000
# time                    1153.400000
# train/box_loss             0.540440
# train/cls_loss             0.281450
# train/dfl_loss             0.865050
# metrics/precision(B)       0.979600
# metrics/recall(B)          0.987330
# metrics/mAP50(B)           0.994410
# metrics/mAP50-95(B)        0.868990
# val/box_loss               0.532330
# val/cls_loss               0.259940
# val/dfl_loss               0.861680
# lr/pg0                     0.000086
# lr/pg1                     0.000086
# lr/pg2                     0.000086
# Name: 29, dtype: float64

# %%
#размер модели
from pathlib import Path

model = Path("runs/detect/train-3/weights/best.pt")

size = model.stat().st_size / (1024*1024)

print(size)
# Out:
# 5.957003593444824
