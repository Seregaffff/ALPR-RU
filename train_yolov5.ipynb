# %%
# !python repositories/yolov5/train.py --img 640 --batch 16 --epochs 30 --data dataset/data_yolov5.yaml --weights yolov5s.pt --project runs --name yolov5
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset/data_yolov5.yaml, hyp=repositories\yolov5\data\hyps\hyp.scratch-low.yaml, epochs=30, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=repositories\yolov5\data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs, name=yolov5, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5
# YOLOv5  v7.0-506-g0675a31b Python-3.11.8 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1070 Ti, 8192MiB)
#
# ...
