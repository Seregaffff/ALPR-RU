# %%
from ultralytics import YOLO

model = YOLO('yolov10n.pt')
model.train(data='dataset/data.yaml', epochs=30, imgsz=640, batch=16, project='runs', name='yolov10')
# Out:
# Ultralytics 8.4.82  Python-3.11.8 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1070 Ti, 8192MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov9-c.pt')
model.train(data='dataset/data.yaml', epochs=30, imgsz=640, batch=16, project='runs', name='yolov9')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\Downloads\ALPR-RU\venv\Lib\site-packages\ultralytics\nn\tasks.py:1654, in torch_safe_load(weight, safe_only)
#    1653 try:
# -> 1654     ckpt = _load()
#    1656 except RuntimeError as e:
#    1657     # Recover only a corrupt cached official asset requested by bare name; never touch user-supplied paths.
#
# File ~\Downloads\ALPR-RU\venv\Lib\site-packages\ultralytics\nn\tasks.py:1651, in torch_safe_load.<locals>._load()
#    1650         return torch_load(file, map_location="cpu", weights_only=True)
# -> 1651 return torch_load(file, map_location="cpu")
#
# File ~\Downloads\ALPR-RU\venv\Lib\site-packages\ultralytics\utils\patches.py:181, in torch_load(*args, **kwargs)
#     179     kwargs["weights_only"] = False
# --> 181 return torch.load(*args, **kwargs)
#
# ...
